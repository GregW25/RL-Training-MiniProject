# %%
# !curl -LsSf https://astral.sh/uv/install.sh | sh

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/WhoKnowsssss/RL-Training-MiniProject.git && mv RL-Training-MiniProject/ mjlab/

# %%
# !cd mjlab/ && git checkout main

# %% [markdown]
# Change TASK_PATH and ASSET_PATH to your local path on drive

# %%
# change this to your path
TASK_PATH = "./drive/MyDrive/homework/292/mjlab/src/mjlab/tasks/"

ASSET_PATH = "./drive/MyDrive/homework/292/mjlab/src/mjlab/asset_zoo"

# %%
# !cp {TASK_PATH}/backflip/ ./mjlab/src/mjlab/tasks/ -r
# !cp {TASK_PATH}/velocity/velocity_env_cfg.py ./mjlab/src/mjlab/tasks/velocity/

# %%
# !cp {ASSET_PATH}/robots/__init__.py ./mjlab/src/mjlab/asset_zoo/robots/
# !cp {ASSET_PATH}/robots/unitree_go1/go1_constants.py ./mjlab/src/mjlab/asset_zoo/robots/unitree_go1/
# !cp {ASSET_PATH}/robots/unitree_go2/go2_constants.py ./mjlab/src/mjlab/asset_zoo/robots/unitree_go2/

# %% [markdown]
# Training on CoLab

# %%
# visualization
# %load_ext tensorboard
# %tensorboard --logdir /content/mjlab/logs/rsl_rl/go2_backflip

# %%
# training
# !cd mjlab && MUJOCO_GL=egl uv run train Mjlab-Backflip-Flat-Unitree-Go2 --env.scene.num-envs 4096

# %% [markdown]
# Visualization on Colab

# %%
import subprocess
import sys

process = subprocess.Popen(
    [
      "uv",
      "run",
      "play",
      "Mjlab-Backflip-Flat-Unitree-Go2",
      "--checkpoint_file={your_path}",
    ],
    cwd="mjlab",
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    universal_newlines=True,
    bufsize=1,
)

for line in process.stdout:
    print(line, end='')
    sys.stdout.flush()

    if 'serving' in line.lower() or 'running on' in line.lower() or '8081' in line:
        print("\n" + "="*50)
        print("✅ Server is running! Execute the next cell to view.")
        print("="*50)
        break

# %%
from google.colab import output

output.serve_kernel_port_as_iframe(8081)
